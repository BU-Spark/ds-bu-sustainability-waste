# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# Reading Files
df39880 = pd.read_csv('combined/combined_39880_from.csv')
df39878 = pd.read_csv('combined/combined_39878_from.csv')
df24990 = pd.read_csv('combined/combined_24990_from.csv')
df39874 = pd.read_csv('combined/combined_39874_from.csv')
df39693 = pd.read_csv('combined/combined_39693_from.csv')
df39692 = pd.read_csv('combined/combined_39692_from.csv')
df39691 = pd.read_csv('combined/combined_39691_from.csv')
df39689 = pd.read_csv('combined/combined_39689_from.csv')
df39688 = pd.read_csv('combined/combined_39688_from.csv')
df39686 = pd.read_csv('combined/combined_39686_from.csv')
df39686 = pd.read_csv('combined/combined_39686_from.csv')
df39685 = pd.read_csv('combined/combined_39685_from.csv')
df39674 = pd.read_csv('combined/combined_39674_from.csv')
df39673 = pd.read_csv('combined/combined_39673_from.csv')
df39671 = pd.read_csv('combined/combined_39671_from.csv')
df39669 = pd.read_csv('combined/combined_39669_from.csv')
df39668 = pd.read_csv('combined/combined_39668_from.csv')
df39667 = pd.read_csv('combined/combined_39667_from.csv')
df39665 = pd.read_csv('combined/combined_39665_from.csv')
df39600 = pd.read_csv('combined/combined_39600_from.csv')
df39599 = pd.read_csv('combined/combined_39599_from.csv')
df39569 = pd.read_csv('combined/combined_39569_from.csv')
df24668 = pd.read_csv('combined/combined_24668_from.csv')
df24572 = pd.read_csv('combined/combined_24572_from.csv')
df24363 = pd.read_csv('combined/combined_24363_from.csv')

# PSI_Readings_with_Weather_2023-01-04_1026
psi_w = pd.read_csv('data/PSI_Readings_with_Weather_2023-01-04_1026.csv')

# Device # (Serial #), Location Name, Empty and Full notification and containers pickup data
hrpu = pd.read_csv('data/Hauler_Response_Pick-Up_2023-01-04_1018.csv')

# Device # (Serial #), Location Name, All "events", Tracks any issues with the devices
events = pd.read_csv('data/Events_2023-01-04_1022.csv')

# Device # (Serial #), Location Name, All "events", Tracks any issues with the devices
dcf = pd.read_csv('data/Device_Compaction_Frequency_2023-01-04_1029.csv')

# Device # (Serial #), Location Name, All "events", Tracks any issues with the devices
dcf2 = pd.read_csv('data/Device_Compaction_Frequency_2023-01-04_1019.csv')

# Device # (Serial #), Location Name, All "events", Tracks any issues with the devices
budw = pd.read_excel('data/BU_Daily_Weights_FY22.xlsx')
# Out:
# /var/folders/3m/qlyn2slj1hlc6p0y780lxt7h0000gn/T/ipykernel_26879/929229793.py:39: DtypeWarning: Columns (18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   events = pd.read_csv('data/Events_2023-01-04_1022.csv')

# %%
# Compare PSI to temp over a date period for a single file 39880
plt.scatter(df39880['readingDtUtz'], df39880['valuePsi']/10)
plt.scatter(df39880['readingDtUtz'], df39880['celsius'])
plt.title("Temerature to PSI for reading 39880")
plt.xlabel("Temperature")
plt.ylabel("PSI")
# Out:
# Text(0, 0.5, 'PSI')

# %%
# Plotting valuse as a linear plot 
plt.plot(df39880['readingDtUtz'], df39880['valuePsi'])
plt.plot(df39880['readingDtUtz'], df39880['celsius'])
plt.title("Temerature to PSI for reading 39880")
plt.xlabel("Temperature")
plt.ylabel("PSI")
# Out:
# Text(0, 0.5, 'PSI')

# %%
# Plot of reading for whole year spliited by months
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.bar(df39880['readingDtUtz'], df39880['valuePsi']/10)
plt.bar(df39880['readingDtUtz'], df39880['celsius'])
# plt.axvline(x = '2021-09-02T13:20:48', color = 'r', label = 'months August 21')
# plt.text('2021-09-02T13:20:48',150,'August 21',rotation=90)
# plt.axvline(x = '2021-10-02T11:30:25', color = 'r', label = 'months September 21')
# plt.text('2021-10-02T11:30:25',150,'September 21',rotation=90)
# plt.axvline(x = '2021-11-04T10:18:34', color = 'r', label = 'months October 21')
# plt.text('2021-11-04T10:18:34',150,'October 21',rotation=90)
# plt.axvline(x = '2021-12-02T09:29:21', color = 'r', label = 'months November 21')
# plt.text('2021-12-02T09:29:21',150,'November 21',rotation=90)
# plt.axvline(x = '2022-01-02T09:44:09', color = 'r', label = 'months December 21')
# plt.text('2022-01-02T09:44:09',150,'December 21',rotation=90)
# plt.axvline(x = '2022-02-01T15:45:54', color = 'r', label = 'months January 22')
# plt.text('2022-02-01T15:45:54',150,'January 22',rotation=90)
# plt.axvline(x = '2022-03-01T09:51:27', color = 'r', label = 'months February 22')
# plt.text('2022-03-01T09:51:27',150,'February 22',rotation=90)
# plt.axvline(x = '2022-03-31T18:49:11', color = 'r', label = 'months March 22')
# plt.text('2022-03-31T18:49:11',150,'March 22',rotation=90)
# plt.axvline(x = '2022-04-30T23:14:49', color = 'r', label = 'months April 22')
# plt.text('2022-04-30T23:14:49',150,'April 22',rotation=90)
# plt.axvline(x = '2022-05-29T12:21:57', color = 'r', label = 'months May 22')
# plt.text('2022-05-29T12:21:57',150,'May 22',rotation=90)
# plt.axvline(x = '2022-06-28T22:57:54', color = 'r', label = 'months June 22')
# plt.text('2022-06-28T22:57:54',150,'June 22',rotation=90)
# plt.axvline(x = '2022-07-30T23:24:51', color = 'r', label = 'months July 22')
# plt.text('2022-07-30T23:24:51',150,'July 22',rotation=90)
# plt.axvline(x = '2022-08-31T18:44:13', color = 'r', label = 'months August 22')
# plt.text('2022-08-31T18:44:13',150,'August 22',rotation=90)
# plt.axvline(x = '2022-09-30T21:42:20', color = 'r', label = 'months September 22')
# plt.text('2022-09-30T21:42:20',150,'September 22',rotation=90)

b = pd.to_datetime(df39880['readingDtUtz'],format='%Y-%m-%dT%H:%M:%S')
# create a pandas dataframe with the datetime objects
df = pd.DataFrame({'date': b, 'value': range(len(b))})
plt.xticks([1,200,400,600,800,1000,1200,1400,1600,1800], rotation='vertical')
plt.title("Temerature to PSI for reading 39880")
plt.xlabel("Temperature")
plt.ylabel("PSI")

months = df.groupby(pd.Grouper(key='date', freq='M')).sum()
months
# Out:
#              value
# date
# 2021-08-31   13636
# 2021-09-30  168624
# 2021-10-31   52137
# 2021-11-30   57148
# 2021-12-31  105264
# 2022-01-31  207701
# 2022-02-28  386349
# 2022-03-31  193461
# 2022-04-30   55080
# 2022-05-31  129822
# 2022-06-30   50718
# 2022-07-31    5484
# 2022-08-31   78705
# 2022-09-30  120235
# 2022-10-31    3746

# %%
# Plot for reading 24990
f = plt.figure()
f.set_figwidth(30)
f.set_figheight(5)
plt.bar(df24990['readingDtUtz'], df24990['valuePsi']/10, label='Psi')
plt.bar(df24990['readingDtUtz'], df24990['celsius'], label='Temerature')
plt.xticks([1,200,400,600,800,1000,1200,1400,1600,1800,2000,2200,2400,2600,2800,3000,3200,3400,3600,3800,4000,4200,4400,4600,4800,5000], rotation='vertical')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.bar(df39878['readingDtUtz'], df39878['valuePsi']/10)
plt.bar(df39878['readingDtUtz'], df39878['celsius'])
plt.xticks([1,200,400,600,800,1000,1200,1400,1600,1800,2000,2200,2400,2600,2800,3000,3200,3400,3600,3800,4000,4200,4400,4600,4800,5000], rotation='vertical')
plt.title("Temerature to PSI for reading 39878")
plt.xlabel("Temperature")
plt.ylabel("PSI")

plt.show()

# %%
# Example of unclean data

# Sorting 
df39880 = df39880.sort_values(by=['readingDtUtz'], ascending=True)
redings = df39880.iloc[640:710]
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(10)
plt.plot(redings['readingDtUtz'], redings['valuePsi']/10)
plt.plot(redings['readingDtUtz'], redings['celsius'])
plt.title("Temerature to PSI for reading 39880 uncleaned")
plt.xlabel("Temperature")
plt.ylabel("PSI")
plt.xticks(rotation=90)
plt.show()

redings
# Out:
#              readingDtUtz  valuePsi  celsius  fahrenheit
# 1475  2022-02-16T16:21:39      1336    -0.37      31.334
# 1476  2022-02-16T16:22:42      1352    -0.37      31.334
# 1477  2022-02-16T16:23:44      1176    -0.37      31.334
# 1478  2022-02-16T16:24:20      1240    -0.37      31.334
# 1479  2022-02-17T14:28:52      1248    16.03      60.854
# ...                   ...       ...      ...         ...
# 1540  2022-02-19T14:16:45       424     0.12      32.216
# 1541  2022-02-20T12:52:22       480   -14.13       6.566
# 1542  2022-02-20T12:53:31       456   -14.13       6.566
# 1543  2022-02-20T14:47:24       464    -4.78      23.396
# 1544  2022-02-20T14:47:58       448    -4.78      23.396
#
# [70 rows x 4 columns]

# %%
# Number of readings per month

# Convert datetime column to datetime objects
df39880['readingDtUtz'] = pd.to_datetime(df39880['readingDtUtz'])

# Group by day
grouped_df = df39880.groupby(pd.Grouper(key='readingDtUtz', freq='M')).size()

print(grouped_df)
# Out:
# readingDtUtz
# 2021-08-31      8
# 2021-09-30     96
# 2021-10-31     54
# 2021-11-30     56
# 2021-12-31     96
# 2022-01-31    169
# 2022-02-28    267
# 2022-03-31    118
# 2022-04-30    324
# 2022-05-31    281
# 2022-06-30     79
# 2022-07-31      8
# 2022-08-31    106
# 2022-09-30    139
# 2022-10-31      4
# Freq: M, dtype: int64

# %%
# d = psi_w.groupby('Serial No.').size()
d31180 = psi_w.loc[psi_w['Serial No.'] == 31180]
# f = plt.figure()
# f.set_figwidth(20)
# f.set_figheight(5)
# plt.plot(d31180['Reading Date'], d31180['Reading'])
d31180
# Out:
#                  Account                     Site                      Device  \
# 0      Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 1      Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 2      Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 39     Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 40     Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# ...                  ...                      ...                         ...
# 99964  Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 99965  Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 99978  Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 99979  Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
# 99980  Boston University  BU #82 Warren Towers 35  BU #82 Warren Towers 35 Yd
#
# ...

# %%
# weights = budw.loc[budw['Customer Key'] == 31769.0]
weights_r = budw.loc[(budw['Customer Key'] == 31769.0) & (budw['Material'] == 'Recycling')]
weights_c = budw.loc[(budw['Customer Key'] == 31769.0) & (budw['Material'] == 'Compost')]
weights_t = budw.loc[(budw['Customer Key'] == 31769.0) & (budw['Material'] == 'Trash')]

weights_c = weights_c.sort_values(by=['Work Order Date'], ascending=True)
weights_c['Work Order Date'] = weights_c['Work Order Date'].mask(weights_c['Work Order Date'].dt.year == 2023, 
                             weights_c['Work Order Date'] + pd.offsets.DateOffset(year=2022))


f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(weights_r['Work Order Date'], weights_r['Tons'], label='recycle')
# plt.plot(weights_c['Work Order Date'], weights_c['Tons'], label='compost')
plt.plot(weights_t['Work Order Date'], weights_t['Tons']/10, label='trash')
plt.title("Recycle vs trash for location 31769")
plt.xlabel("Date")
plt.ylabel("Tons")
plt.legend()
# print(weights_c['Work Order Date'].to_list())
# Out:
# /var/folders/3m/qlyn2slj1hlc6p0y780lxt7h0000gn/T/ipykernel_26879/3278648248.py:8: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   weights_c['Work Order Date'] + pd.offsets.DateOffset(year=2022))

# %%
# weights = budw.groupby('Customer Key').size()


weights_r = budw.loc[(budw['Customer Key'] == 31977.0) & (budw['Material'] == 'Recycling')]
weights_c = budw.loc[(budw['Customer Key'] == 31977.0) & (budw['Material'] == 'Compost')]
weights_t = budw.loc[(budw['Customer Key'] == 31977.0) & (budw['Material'] == 'Trash')]

# weights_c = weights_c.sort_values(by=['Work Order Date'], ascending=True)
# weights_c['Work Order Date'] = weights_c['Work Order Date'].mask(weights_c['Work Order Date'].dt.year == 2023, 
#                              weights_c['Work Order Date'] + pd.offsets.DateOffset(year=2022))


f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(weights_r['Work Order Date'], weights_r['Tons'], label='recycle')
plt.plot(weights_c['Work Order Date'], weights_c['Tons'], label='compost')
plt.plot(weights_t['Work Order Date'], weights_t['Tons']/10, label='trash')
plt.title("Recycle vs trash vs compost for location 31769")
plt.xlabel("Date")
plt.ylabel("Tons")
plt.legend()

# %%
# Locations sorted by number of records
weights = budw.groupby('Customer Key').size()
print(weights.sort_values())
# Out:
# Customer Key
# 31986.0      1
# 31591.0      1
# 32800.0      2
# 31583.0      3
# 33167.0      3
#           ...
# 31903.0    379
# 31769.0    398
# 31830.0    425
# 31771.0    433
# 31977.0    477
# Length: 151, dtype: int64

# %%
# Total compost trash and recycling 
weights = budw.groupby('Material').size()
print(weights.sort_values())
# Out:
# Material
# Compost       1906
# Trash         4897
# Recycling    11371
# dtype: int64
